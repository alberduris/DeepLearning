# %% [markdown]
# # Char RNN
#
# 1. OneHot via tf.one_hot()

# %%
import tensorflow as tf
import NLP_Utils as nlp
import time
import numpy as np

# %% [markdown]
# ## Hyperparams

# %%
#Data
filename = 'tiny_shakespeare.txt'

#Cell
state_size = 200 #Default: 200

#Batches & Vocab
batch_size = 64 #Default: 64
seq_length = 50 #Default: 50
overlap = 25 #Default 25
vocab_strategy = 'all'

#Test
test_size = 300 #Default: 300

# %% [markdown]
# ## Read Data & Manage Batches

# %%
batchManager = nlp.BatchManager()
batchManager.set_params(filename,batch_size,overlap,seq_length,vocab_strategy,mode='dense')
batchManager.get_params()

num_batches = batchManager._num_batches
vocab_size = batchManager._vocab_size
# Out:
# @params:
# [filename : "tiny_shakespeare.txt"]
# [text : "First Citi"]
# [text_size : 1115394]
# [vocab : ['h', ',', '3', 'p', 'D']]
# [vocab_size : 65]
# [batch_size : 64]
# [seq_length : 25]
# [overlap : 50]
# [num_batches : 348]

# %%
batchManager.stats()
# Out:
# The corpus has 1115394 characters
# Configuration:
# [batch_size : 64]
# [seq_length : 25]
# [overlap : 50]
#
# The current configuration gives us 348 batches of 64 observations each one looking 25 steps in the past and overlapping -25 steps

# %% [markdown]
# ## Placeholders

# %%
seq = tf.placeholder(dtype=tf.int32,shape=[None,None],name='seq') #[Batch_size x seq_length]
seq_one_hot = tf.one_hot(seq,vocab_size,name='seq_one_hot') #El que se usa en la RNN

temperature = tf.placeholder(tf.float32)

# %% [markdown]
# ## Create RNN cell

# %%
cell = tf.contrib.rnn.BasicRNNCell(num_units=state_size)

'''
batch_size : seq.get_shape()[0] instead of 'batch_size' 
in order to work with variable seq length, this is, for testing char by char
'''
zero_state = cell.zero_state(batch_size=tf.shape(seq)[0],dtype=tf.float32) 


in_state = tf.placeholder_with_default(input=zero_state,shape=[None,state_size])

# %%
output, out_state = tf.nn.dynamic_rnn(cell=cell,inputs=seq_one_hot,initial_state=in_state)

# %% [markdown]
# ## Create model

# %%
logits= tf.contrib.layers.fully_connected(inputs=output,num_outputs=vocab_size,activation_fn=None)

loss = tf.reduce_sum(tf.nn.softmax_cross_entropy_with_logits(logits=logits[:,:-1],labels=seq_one_hot[:,1:]))

sample = tf.multinomial(logits=logits[:,-1],num_samples=1)[:,0]

# %%
optimizer = tf.train.AdamOptimizer(0.001).minimize(loss)

# %% [markdown]
# ## Train

# %%
num_epochs = 10

display_freq = num_batches//10

loss_list = list()
av_loss_list = list()

step = 0

last_epoch = -1

with tf.Session() as sess:
    start = time.time()
    tf.global_variables_initializer().run()
    
    for batchX,batchY,epoch in batchManager.generate_batches(num_epochs=num_epochs):
        
        if(last_epoch != epoch):
            print('Epoch %d:' % epoch)
            last_epoch = epoch
        
        
        _loss,_,_ = sess.run([loss,optimizer,seq_one_hot],{seq:batchX})
        
        loss_list.append(_loss)
        
        
        if(step % display_freq == 0):            
            if len(loss_list)>1: av_loss_list.append(np.average(a=loss_list[-display_freq]))
            
            print('At step %d:%d - Loss: %.2f - Elapsed time: %s' %(epoch,step,_loss,(time.time()-start)))
            
            ###TEST###
            sentence = 'A'
            state = None
            for _ in range(test_size):
                batch = [batchManager.vocab_encode(sentence[-1])] #Last character in sentence
                feed = {seq : batch}
                
                if state is not None: #First is none and must be None
                    feed.update({in_state:state})
                
                index,state = sess.run([sample,out_state],feed)
                sentence += batchManager.vocab_decode(index)
            print(sentence,'\n')
            ##########
            start = time.time()
            
        step += 1
# Out:
# Epoch 0:
# At step 0:0 - Loss: 6418.64 - Elapsed time: 2.1212704181671143
# AX,egr-AgBHtS&kNR&$JwNAMvn WngranC ?DKZ'aFtmhgTAS,UnxWC-kgvJCIcdBWH:3z?geGmxVA-gEos$gHeQlpLSf dyAVyo!NJz?dIpoCJ&,cAW3aAXdBY;XPjqd vXhrkfL?E.uQtoSvsg'wQSp&rMdCsix:MKA-Z:xVL
# yVvxiY;J,oShNV&uD3et;MCemtptXNBnoeAxlKlbWoGoV&Q mh
# gfq!$HOA-rsVq:-qqRltfHTyA,tTUaGPrcFBP:tMjFLyhYqvvfX;EssRLyp'PkQ$$hBNEv''FYGup$
#
# At step 0:34 - Loss: 4894.62 - Elapsed time: 1.4570021629333496
# A?llEhI a, neetd,on tImfh uisp.hh'eSa'leP imtnbe
# ANhtmnobknsO
# eanM
#
# :Nwpl
# eguT
# oBh. i
# otrec Oi:ttsr
# eameh
# l.?SAmpaMe n,n Ivmard,orwspLSlNtWnewlhn
# y dlmcth
# yemwImo
# bC:eHt hhm af  raBirO
#  -i,
# Cochoa
#  a A  sAlw kOOw keebs,hsgN UgeiSlO AIevmthe,fNnr
# tiayI h.VH oaheDmsuy
# nesncrnl RtiThnOsasauch ue,flkee
#
# At step 0:68 - Loss: 4935.20 - Elapsed time: 1.4595043659210205
# AS-aOnnfh:kt hallgare od
# fTnrn ene oaea,iinIcra
# Whennln,I:e, c&gweesaerhi lchrih,
# W:tctoroed  spcuw
# tC :dO Co irttrDSrs-nlwrtfdtlolu,B,Cndee,re!rd es   fedeoT irfe,Ntesrr.   eodLbotlr Hndad fAwoI :rf?yr
# Cist d
# -h'ee  t
# ce:d eTLr:o B
# olau s  bv uwd tebsdmo  t iiu oth age , doen 'rvIrakunsrel lto,,nW
#
# At step 0:102 - Loss: 4540.63 - Elapsed time: 1.466019868850708
# AZZmaid nf no doKeae wo drdve nofIhoI smuo, t eh do:lb forsshatnes
# ohVce:htrnceolrwd iwshtse seurw.ro
# tTd
# ac se t wd  main,
# rrimhgaameld ih, drkore youdt ly nouiwlll, Oonyuon usmy ,
# rsl gurhee ahenk nool ohaf Gewau iandmrkttr,s,
# no sreso sefcttarrshesnrelleineGg aoeod ripdeic
# hF,ns Dnr tone hc, iowM
#
# At step 0:136 - Loss: 4079.66 - Elapsed time: 1.4985976219177246
# A$, lid tho,yew aiHiBg deteialTH
# Dini'RiEe at aiee:lBekiEfil3 thrm, n
# kt aou shyhdumwsuoithin yeo he teif wgoole
# aosp
# MosD 'h lhour wo
# eAgHy aGes eclaIE Rt wod-boieF thisnd si, n:usnwc toibtblns rn ahe Watine
# s
# Wietthtne aotmgnce yocknWmomd wotnd olce meele oo btiy tias eanec lkhgg and tY sfold do l
#
# At step 0:170 - Loss: 4003.25 - Elapsed time: 1.6554746627807617
# AVV-nTTeo is 't an soeey ca kzvipt too yiwene noummna?:
# BRd to
# ll Iourest od th cursto coithcnt er ilencogei
# io bi: anl kinsTfx-ot bas do-gcots soume wisk wowend ?in gimea, my s aie f
# ref-.,
# BIICIBNew
# O
# HEXEC,GLIr:
# he toure
# kB wease,
#
#
# u3llTl
#  .u, gope,e oh
# an wath tf yinndfdd,
# eyym
# eav? hou ohdt
#  Uh
#
# At step 0:204 - Loss: 4000.74 - Elapsed time: 1.5752816200256348
# Aooue s arorsnf
# sllun:w womehald lo bnto  hen thevercami l sfarlentki
# ttbsr teps.
# wiqf bed th blwfsiyg onein ho gditget
# in, aithet shetI YoiAh my ltJeul  nalhet haotam
# Thol 'he:
#
# An,sGr: W ahe:us, thenn
#  frsere wolan  finies paan hevk wrtfar bo'd,eA feGANI E:
# ThoC be noke we LFli hbl tho hetsgss seo
#
# At step 0:238 - Loss: 3885.30 - Elapsed time: 1.5868091583251953
# A iald easp,are yin mhe'Te wors uod  or cinks bfarlo,e, Ih marLaI Yl telithikertharR
# lo tich,
# toa nofbr,venifkgr rshacous neveicasp
# sou , inde
# theane lotr roit ange  ir wyliBell,
# Ms, Got ohou foulinn.
#
# SUIAI LEM;X pe t wraHe tits frdan thtm Aly The ho ohe firldox tganthar, be torentng:
# Angmy tou psty
#
# At step 0:272 - Loss: 3725.29 - Elapsed time: 1.5562360286712646
# Athe,gTand tmarer thoo be cn se y il fote tos afe ouuntthi,
# roveraug iokeees Huuk of ifnkein-
# Eott rourethe ty ufst bd yoel!
# WeRe Re nor inne the y borm bneereeefarllltsth
# , ais ay werd me iw coshingt angmt yfur m.o
# nsod mutE dule, fif bethe ds ace acinds oJu leussand porcslan:
# CAte sin to esdritva
#
# At step 0:306 - Loss: 3817.21 - Elapsed time: 1.4915928840637207
# Aeg bithe, inhy, hou tiachen
# medhinh .i? LAtO bok aad tor woct wou be imll wired oory matd hess Eo'l foredod het ho ar therllkjust cot, sin tanee,
# DRNsKVENNIE::NLee'f syis w the thurriby mord yture oreals ron moplace anss cacllinc ferimetiAnS this thuuh y'uigm ar tn thenve:
# Tard oe tohas d: filheu ho
#
# At step 0:340 - Loss: 3829.35 - Elapsed time: 1.4925837516784668
# At:?:
#
# hobsI :! nove iyouth
#
# HyBes:
# Ohis ooor oo$ww thsrgate, h oustr
# and, ar copeatC
# jyD, whele dit dawncmere walh lcyev in? wrmeam, fouscoret ochathingstinkeat,
# tessiigs spersersem.
#
# BECOII:
# I for soulh, pivy dic
# ve that eovey.
#
# UEGCIONH:
# I bl youss
# Jfeeures ftheneik, wele sordeOl bomytnose wouth n
#
# Epoch 1:
# At step 1:374 - Loss: 3403.75 - Elapsed time: 3.5064446926116943
# AV:
# Het is, Wond ber ragnFos,
# STinw my  ar riem , tals lo th ove no be cichouthe , diris hith souy whove
# 'o hid'r gats aramly
# Wouch's heweech, owr peog se , flbCnghet, Serhe deurd
#
# pcond no sullf np tore totn seve touse
# ,Pgorlf ten, bo thin inxtheus,unit . Fowe,-.
# TGIU:SIO:
# ToE$ENAM:
# OO tou, Ie thar,
#
# At step 1:408 - Loss: 3551.74 - Elapsed time: 1.466019868850708
# Awist ar and.
#
# BGAEDiUS:
# Thene ths gongyou
# d.a
# d thd bubt., M mand cod 'stad wist wf the yno whd oury 'f pticbli-,
# Fy me re fuike sorgeth ming;f'N y ans ledeat, couthis, pats m
# iacwerlg!ot illd-s myour? ond bithome yod mave. Afn tot dime
# uovndous sorrand weraud gnore, no dirus the ouchisce! the is n
#
# At step 1:442 - Loss: 3571.01 - Elapsed time: 1.4349465370178223
# AK's: Thond th of keneellirs biwedeR:
# I toH sidqun.
#
# FiA
#  han a eertulef:
# Thafr ghie t yu hie, An whasthes
# .
#
# IEHBs KI Goud rrthee  aally bend
# And henz, chatheecnenI s chown this sent
#
# BDWeEct:
# Tno gorome thans vin hou has or tterhoul tioe, she orvep:
# Cother anocs-,
# Whent mekinge,
# HoRn cliwglt bees y
#
# At step 1:476 - Loss: 3309.60 - Elapsed time: 1.475541591644287
# Ast eis hal mineslt tau doachall chont?
# Thit tha Fpert thish me.
# WhOeLCIOH : caele
# I llolh parte po sher goney aid lis ingArd Lhath
#
# ro, the buy
# Am velesd ha layd
# !ent pn-orim:
# Wo pare,
# An ardd
# anghouss
# Ar, with lf asthe Cruat ns pouthe
# BCHath coarin on thom grea:
# Whet un gelest GfiCrUI
# we my in gheT
#
# At step 1:510 - Loss: 3500.27 - Elapsed time: 1.4925837516784668
# AWdr mnle forle tfat werr gavethen t ou glor?
# Than whars?
#
# BORGORTO:
# We, allagnt.
#
# SUCMIUA:
# Ioth efors nothe wowat sors harcave:
# Je dovexeag suspeveI harse: rackmee qurlidy wapt-jorlwyap hhir lpard igingrouc mond y.
#
# LLOF Oy Eu:
# Ond in mesaush, chare, areat.
#
# BOLIO
# Burnous mom thlvendon ow pandther!
#
# At step 1:544 - Loss: 3421.81 - Elapsed time: 1.430433988571167
# ACy cicems ho dis that y toldst pour hpreast Oromhto toucmrath!
#
# undsalf selr, ond ano
# B'thar her wir hit hot int ard oot neser tong ante thet hake isnishey wermang antul I fake nrdforchsper amer and thade that?
# CRIIV, GoRdREBS:
# Ooras haur Th urisol shasl,
# Dithafly farlf at Gs ith risw therure cafr R
#
# At step 1:578 - Loss: 3449.48 - Elapsed time: 1.4725341796875
# AUd nowhr, it and thy sevenre wawe'd  mo Lues,
# Yom he slouk's Hcomen ta mract?
# RY LI$WRLASOECD:
# Cakey, is and Wotu pr!il oule io dhiin the ifthit I werd's y sande handin now ule thin
#
# rten his ahy y ure demoe hod I blo se peringroP.
# CNTES:
# No meassnnbut,
# Thiy d diven yeowerd oa weale, tres.
#
# KEANI NI
#
# At step 1:612 - Loss: 3461.04 - Elapsed time: 1.4615085124969482
# Ave soont fowthe
# ous yon ar beins got himg'd ham ale ne routhe biksde mhat  n thohe s ipsosr psencacos sere t,estet'laseish we spur mive co boeng:
# Wethy wing theelrdvergind:
# Iro hou sod je,
# owe hemwirt I sore
# Sor churd owe tar meal dof egand ofand dourug nay ungugr fsaro nem,!
#
# LAUKINCHVIN:
# Ty s af
#
# At step 1:646 - Loss: 3257.27 - Elapsed time: 1.503610610961914
# Ass you.
# New, aed fath fien, thand
# Ox wave faJk coproultne mate tu wizl, Tois cfitht hardedcen- Eoll'd ty:
# Sheigiun dimd thou f pron at yourtedreis, thest wabe nesh
# Thay fore hir.
# RUCToO:
# And, it to nhvs ofith hellm thee,
# Patmy Cor, is, of chas.
# Than the yit than mseecerintor, ford nr I peicthis:
# Or
#
# At step 1:680 - Loss: 3255.11 - Elapsed time: 1.619889259338379
# ANI GI Inot manteo mericgher bist
# Ie may haverr youcf wain,,
# I ssace ma god?
#
# PMTMAR:
# Ge, y ors iref your 'lo poofe.
# PhSo eoomlachrt rath, aind ose thrishangw ite telu'd hiverod ail ot tees condsitheck in me tove seorlfone do dern ghas thite do isidthing it wereid.
#
# CUAQUTIO:
# Ey,, worweale, tud nithe
#
# Epoch 2:
# At step 2:714 - Loss: 3323.03 - Elapsed time: 3.384131669998169
# AsCO:
# To cem contse shastsengo g, se bapnood gfis
# Wimes Io
#  tobeis.
# Ou know he chave,
# I face arre ther mos an
# thoun but.
#
# MiAnd LVONCELLACI:
# I, tont dis rove whre pastfermy peit, is of trew, with medibe sh urinl ,a-s citiles
# no
#  pametr now Mrestals make shemy com.
#
# PRCUMERAUS: I ma &on saxe dobcout!
#
# At step 2:748 - Loss: 3380.44 - Elapsed time: 1.610365867614746
# A Ifif lave, th bew the toro gome of your's, wofld burod tt tele west gad have yould pi? theas, I comy chor?:
# Sograndislure irlake'sgen anm mo tore wer, to mot thim'd thelly ur ant ar beesty, fowath the kedo ke tomedd ly miensumsov:
# Sestersto, tist, bearano leve wie re the thundere sot cousart bo syo
# At step 2:782 - Loss: 3375.62 - Elapsed time: 1.5311758518218994
# AzLCCHRiMEI:
# Cy,
# Hodiso of none myod for cotin?
#
# Laptr werd in woll dy ary wim
# ?
#
# AlUNPcREETHA
# Ffort And coude fons mond the wiunt,
# Th my tord fuwell  teqbetith morr theableiss withed her yous nofelers: of trywervin soold,
# To t I porse dame coferingling't-
# Bet spoy m wokes ffoor.
#
# SLON ENVO
# HERTIO:
# F
#
# At step 2:816 - Loss: 3344.92 - Elapsed time: 1.482058048248291
# AN:
# Halds lane dEdon hathous suthen semb goik theast tfy cenous uvouet gook yow ore:
# My ledshen wred spard,I'bl to graikf  ogrdeen male toom ferey kisgerest the if her patte: fot hawsugo klice:
# Hom, aldavis solly
# Hrod wee too nond bots own-contase, for souts iinl is gnaem.
#
# GINs!
# RQQES:
# On bot me hot
#
# At step 2:850 - Loss: 3276.47 - Elapsed time: 1.4810559749603271
# Avd ar,
# Thon ar whon lipll meve ar jeall
# Bus, me this efort'Ml
# Varis, w th a thece, melere,
# Tay lige llint s oild hear and fervence, se fath wourt the king to b'st thay ther ware!
#
# Buther in ara itha peereee
# Toof ghe thof hart nothen woy, afr king dol iweling sound,
# Whare houl quve, hit thay jove's h
#
# At step 2:884 - Loss: 3364.90 - Elapsed time: 1.5186452865600586
# Ar, Comeiig'd, for my y arres.
#
# DUKEzRA:
# Her I se coundy wnthe,
# Hatig toud it ow fad eo iak yom ury foort!-
# Bov EoU, She ke, mather came natnote.
# So tod E for my sworg tise your gee?
#
# Frow thing ffor and thou nomy
# Saant.
#
# GUULUKTENLATC:
# Sy urobliek od
#
# Compent os sonow is mattor, and rte teech lisrt
#
# At step 2:918 - Loss: 3413.13 - Elapsed time: 1.4539904594421387
# Ave of y'll sede com akn llve,?
# Hey then and ublind?
# And heamr ths yfrinci,
# Mert boo forew hearen, That'd ghiee-menoo gaike st
# CxmencintitfiD.
#
# KINGWEMZARDLI:
# Fvesher grelp?
#
# LUCEMMER:
# Whauld murs therl ss.
#
# WINTLENHERBANEY:
# My oo dset jutse, fieghin groknd Aoungrent I Leott away hive, feale mind gou
#
# At step 2:952 - Loss: 3332.32 - Elapsed time: 1.5853056907653809
# AWara'd sot beithes wantn mu noi!
# I Sprack, thor manelin by doure est
# Yet areor Cim court anre tou game.
#
# LDUMELEO: I waly, rowe
#
# Ttees, Pot eperit
#
# Aad lyou hald sama fpeny
# erel ty, I whon ing sio buthes ther oond,
# Yot the aourd: iy more thee seite recp!
# lo ches--
# yous dot ioperoy been swe, ser ith
#
# At step 2:986 - Loss: 3096.03 - Elapsed time: 1.604363203048706
# An bo han youd'l ste!?
#
# ITl, I wo loug thu beslive of werd shat have is ald secy se briWedes al queegnond, too
# Foor yous in tise.
#
# CAmI be tha kiblo keis te y there alfoth fergsondired Intenba t te sa deacpde.
#
# Te but? wiel, weathen allo e failh you my ofay.
# Hond, blt if th fis beat'ante premine in.-
#
# At step 2:1020 - Loss: 3249.34 - Elapsed time: 1.5407023429870605
# Aks all wayou trous are shae houle ly:
# My lorse wit anbuin wo bug isid, bedrshir.
#
# CAORIO:
# He thay,
# Pace,
# Ma duce ing ir ty aid oo patouss.
#
# ur ayferesexlos, hear bet,
# AndI llo n think,
# Wit hed 'e wis wate sfalle by the not with fay de y thenind,
# Tate aprsbrangr.
# Tach mid?
# 'tald h
# velig to ysure the
#
# Epoch 3:
# At step 3:1054 - Loss: 3348.43 - Elapsed time: 3.363582134246826
# A notels re oube
# Sh
# RINCIOYDZBAONE:
# I patsen tome tuty bughir thapet,
# Diecl him so dsery fro d the obes-jould.
# IXkAgl ou ang not forte
# Bse ham the ho bus cagenmeav, anden ttuno dows liot in babedusich
# Biishilists fore hall onither.
#
# SA
# MISCA:
# I Anj dulso
# Angend br mo got res! ry be kidm, ou she lundi
#
# At step 3:1088 - Loss: 3221.29 - Elapsed time: 1.4284286499023438
# A
# Tige framsinctores,
# And, thal bupad if at ordeave:
# Nor youthes, Csancer wesar an ir.
# TCAP-ORINKIN:
# No lowe, the gfishe counon.
#
# E viss bryin tizen:
# He hies!
#
# Ferstreir the sarkingyoure, me ha thow'ak' fxol woscenbrsary tous thour nom nobe of peapeall muld you, live misurngcon,
# Nows, I his, if my en
#
# At step 3:1122 - Loss: 3291.07 - Elapsed time: 1.4294312000274658
# Allefad's chsord, ankence
# King afather os lire!
#
# BAOTERNABE:
# Hars noblingnget
# Tole si-BocT:
# Bithingem nacthous.
#
# OLARUSHZ:
# He fakno seare pease ghare
# Tse woth the veld iy Pra, Im ourulu thisef Agu bye
#
# s'lly couro,
# Ber misem trad larcou fat Or couther to thturid abllom.
#
# MLARk:
# He d ke cowncou to whe
#
# At step 3:1156 - Loss: 3262.87 - Elapsed time: 1.4695277214050293
# AHHAR:
# Gord nfpreaked's nath ous ma age tale ound nyoury.
#
# CLANE:
# Mall.
#
# DONT SIK:
# G pulats ave it.
# Any not fela dinat foos mo looth urserd'd il chise ha lo son having dy ine betteng ivisse?
#
# CIOF YONCHRORY:VQyUETh theagholl com fe to houl s'diwe'l io thay ous
# wny chat to sire tith eebure:
# Thens live
#
# At step 3:1190 - Loss: 3349.53 - Elapsed time: 1.460505723953247
# An, out lakeat is is beall.
# To thet, sorso.
#
# BLORZGBORT:
# Whit ain noul''sp gen thee tod the pea.
#
# Thiththe thom fo som'n-beis.
#
# BexThe For Haves wild feaill 'e stoller.
#
# for murint thaug nothsuld.
# These denth me king!
# Thol shers hat I sadw ise,
# Wave t thee, ane:
# RGustere poage t
# Thef rustere wnond or
#
# At step 3:1224 - Loss: 3190.48 - Elapsed time: 1.4705302715301514
# Ard whent. char seaven'st bust:
# I so, shave thot anagr my, hit minu st ercemene lave shas ofshe wouls--
# ORast owthide whall!
# Cove, te t tak oug, a king thous nongs upferr chashsen
# I lik' Jubadist?
#
# JYit to has somdds hell-nd ed noual- too fer sting thamp woet Rage? Dhed cains fithes sere, now not hes
#
# At step 3:1258 - Loss: 3089.43 - Elapsed time: 1.4605052471160889
# A.
#
# CERWASD:
# Ge: foo hok seill.
# The tlathre weoving,
# Me nos sow, dears, 'scam'd farrtise dond bute fupkins mono toke ghor my heark:
# Now, ther you the test ffratwitvenh Shele munets, thet by trefrif det GidnSeD:
# Jade, wh, he wine wimt cearost, but, lasty andes's in thin are blthenver.
# But benSthen, in
#
# At step 3:1292 - Loss: 3345.77 - Elapsed time: 1.4655182361602783
# A hou san.
#
# PETIOLS:
# So'll dog thid sored, I eeally:
# But linsse
# And gcachich ma bees w madea in bathe sale ofurass then, buenveraginep, my sorlanl Pdoro hearifids sarins
#  har ma thishol in live,
# Onas mear'ars bye
# Inkenor wote if byoud e swill sor helr ment mitho mane
#
# Ofaund, at your strles?
# Now an t
#
# At step 3:1326 - Loss: 3101.67 - Elapsed time: 1.4670226573944092
# A whet, your our fmeoe, I she cople? Now tuengerlos feer,
# Thot I Hoveney purouspurean tor ip thence
# Bot the houlsth
# ng nom that faYtu har
# Unwirde sio, ofmysraave te your stouncl you you sintle toouch?
#
# PEOs mo
# Theand the kigen en you's.
#
# E II wher wore,
# And, pormy, enour
# cous in ereaad the bees:
# With
#
# At step 3:1360 - Loss: 2987.21 - Elapsed time: 1.4640145301818848
# A fris! Haprinith meens forman nom, bxtmering
# toine on mealo.
#
# CLEYIAS:
# Daye, not ang taic'st tue gote tu phit po?
#
# Firses mhalavem brothere, noy bead, wil me fat kive you lich s stazenthe mise ayo harmy?
# HeSray, and matt in on to muld with
# your le ters wolle nou thou calland fio fea hpars.
#
# SUcELIUI
#
# Epoch 4:
# At step 4:1394 - Loss: 3173.80 - Elapsed time: 3.353550910949707
# A butowenis now
# Madcand,
# My flomes:
# I t supeving.
#
# LONTANO:
# Aha matcane hare toentornom,
# To cealisil
# Se it rake,
# And as,
# Yound beenzui grtu win be steend efrell we ta time ouse anreas
# ay I watt on toke toiendyou batos of the lindo, sheld mer ere,--doutherad ins
# whe thaur sannob
#
# That now.
# ON OSNE:
# I
#
# At step 4:1428 - Loss: 3092.86 - Elapsed time: 1.4640192985534668
# And and shomeng this nold
# And stota, ie.
#
# Pravin
# Y Vrachis
# Firge pieg, the hace, th is with natl and ysur lay taks drest
# Not ou beave, sispe
# The thave stone.
#
# Locks, min,
# Ir withidm, to ty bee: the come madunds, whe nowis to and chare priverimed the wingh?
#
# Frist gAthzef,
# Then! wolf.
#
# ROMIONUS:
# To fa
#
# At step 4:1462 - Loss: 3158.03 - Elapsed time: 1.4685254096984863
# Ag he mive Julant
# And surey my sen, not hecr dome
# Dr word mares gabbyon woun, ksous-laid, dalu dot.
# But but doudts thes If a sleast me ig uerenju, anw
# Inds and potiichas.
#
# Hon, deamist runtly freEd sod an whas
# I statt ar wothes.
# And:
# Now, gedito.
#
# JROTES:
# Whate tingeese pingrhes
# That
# Ind I sare tie z
#
# At step 4:1496 - Loss: 3267.43 - Elapsed time: 1.4675226211547852
# And heatr anvarnoum, in thal cander, I to cere to hath wall't thepree fforstortong arsunk' for tanderuch,
# Why,
# I way, frla nust al onagl.
# Os Tiy consid ingu batd thit Growe?
#
# KING RICHIRD III:
# Vryad, Marighar:
# And ald minge teat, to dop te is seen.
#
# CAMTIS:
# What I wame To foree!
# He to houm nit lfinet
#
# At step 4:1530 - Loss: 3214.40 - Elapsed time: 1.4610066413879395
# AY.
#
# BUCHE Craseadn, 'listirta giedse.
#
# GRETHENCH:
# Thoure and poorenmy,
# Te?
#
# LIUG RINGBRDTRUME
# TERHAN: nfid heors, farstowissme haprean.
#
# OUKENVUL:
# Thetk opof chave in the dingm.
#
# TUSHMO:
# Uane font thainge toulang to theme then or shemencs of Hemates is harde.
# Feaze on mance.
#
# OUSHYORD:
# IDmeath's br
# At step 4:1564 - Loss: 3103.98 - Elapsed time: 1.4690260887145996
# A!
# THARD II:
# Mar t suins the mupsertl teysrcawsus no dopp atrem, ix as ingoby that will nipmof tion,
# And now this all Bot, hit dod
# Id enlink eacelay,
# OF ou the this
# not te shoughter we jute
#
# st lepading thus, a tho radd m
# sher tizts, her, non higho thon cours,
# wellin bute thes the ffilldas incos I'se
#
# At step 4:1598 - Loss: 3011.81 - Elapsed time: 1.4595038890838623
# AnVOHAPDLAULERY:
# A: thy eajs hinds oro hich thy alfarnge tous comes,
# Lordermary I wmel. IH llomsengraw't jore!
# Yoult, by for breast And me my hore us omce.
# Toud, I de alais, ane or my fur
# 'ule car dy alpanoles my's hovifor or abmonds nmad'd, soof cint mathsver: med, poro kingen
# Till miat mo
# Prin our
#
# At step 4:1632 - Loss: 3295.89 - Elapsed time: 1.4675228595733643
# An bey mast a savestrin d hive pereor'lo, she pich mes anm boof ca.
#
# KI I lurd at nowirgardt un nee dut frer, and mo becour U shee.
# nilestere wath DGadd forme.
#
# SEANDULE:
# But pesiqual,
# Murtantel't hepest.
#
# HESTWIUS:
# The hour ut in thapr conved e peitat
# Bons cootsere-contwerol betrow'd y for tormuci
#
#
# At step 4:1666 - Loss: 2975.60 - Elapsed time: 1.4595038890838623
# Aid de: by too sor,
#
# o wisp you fay yan be allowa'd
# Brtees,
# En ias bacist
# Af'Thise,
# Soow! prateer:
# Aplowim, thece you Lrar
# Thet four whith eon bithor ulan aimes, est ie nes tio and hind withis,
# Comeling,
# And I us! If cenvers apra torbed
# I heve mose her has not is anoucholl's: of is bure tos you het i
#
# At step 4:1700 - Loss: 3113.52 - Elapsed time: 1.4735431671142578
# ARGSOT:
# ;cy, your all san:
# Coteret my foflags
# In whale  for comesser.
# Le wouch dad, S hour , nea hes ofr
#
# Lot sheled muc my your pothing youe te them loos, bokt your ore
#
# ares in us ther comb of this use
# Buty misher: my topsser corver fof
# I mace comf,
# That mey you gnat Ttoucw you start thanke an yee
#
# At step 4:1734 - Loss: 3207.19 - Elapsed time: 1.4640145301818848
# At sht kent it, onatsen my, wert! Houshel
# Hy. I will allito the hime.
#
# VORULO:
# A whian's, ow haven in crestirmand grave confed him pierin warteagr.
#
# KING ETVANCIO:
# ATisil
# My, whele suall bunter fore.
# And kent hio
#
# Mircaikn Ourant rimpret stast!
#
# AEBALT:
# Then or mas, ano frepo-t hy withord not with m
#
# Epoch 5:
# At step 5:1768 - Loss: 2915.44 - Elapsed time: 3.3350062370300293
# As to dimes, hasay,
# Oo betist Simeno ustentlandon wish of of cain
# the rood
# Wersha dion so.
#
# IO:
# Wit, y thell's souce.
#
# MARYIUS:
# Mis that praper ay ther we stand bohtruchieg to gosous
# Wat hord shere hehale I dowest undlly fous shat thot in the eford hrade thais thit plasse tike?
#
# CORINENAUWI coret on
#
# At step 5:1802 - Loss: 2967.85 - Elapsed time: 1.4284298419952393
# A:
# Say thar I knews,
# This dore,
# That ber inot
# What icerselt.
#
# COMINGUS:
# Mayofrect of bear,
# Tond whest indine mowerc,
# ling.
#
# Locemyouad efor haref and doodt,--For, Oringref.
#
# Firmunts, and tik 'dmot ou hall foo thave home ave vio hor gongughe men.
# If Mortorst juchas:
# Sichan. Howe onterud
# I wiln pear m
#
# At step 5:1836 - Loss: 3239.09 - Elapsed time: 1.4424633979797363
# ABE LraY's ga'd, the wils his cond,
# To ketw the thaud wn to tondespor, Gof in brooke deach, sor Thit dast,
# Tom, his layo, ouk
#
# Farst Weins sear bo bhealt And faid yaf shishars:
# stveng dedsen's breed?
#
# VIICHAED IAlB with enace,
# And my these of Dermccathar?
#
# Fir't En lerele thee porsund,
# Dy longulo se
#
#
# At step 5:1870 - Loss: 3004.33 - Elapsed time: 1.487069845199585
# Agd,
# For Laid sheplownAl's at to but linceSTer, tio not hom store thil igrich in some
# Then peain,
# Has you fringus grow,
# Sthem tith age tave haicizes,
# And cenw
# Do Erwith merres the kin. Clebres ty your hoslar mart:
# Pay.
#
# JERWHUS:
# O, your digus natert an, lord mo the I pid Whaco'd my mming ath wello g
#
# At step 5:1904 - Loss: 3071.49 - Elapsed time: 1.5512239933013916
# A thes, furnien Of S.
#
# BOLCET:
# Onaly than' gind of doun now-thincanctol's il ay, hear sat,
# Rave yot, hrmed: I woum dyoust.
#
# RENBELI:
# My thuin yout ow spins, iclise cayle, heack lote'd come!
# Thle tha lyouth deld'. Heave.
# HEO, I curss, Cepprose so, feel, I sharl is coumse Hirdl of Glowh samalist you mh
#
# At step 5:1938 - Loss: 3052.71 - Elapsed time: 1.4329402446746826
# ANBS:
# Will betall with now
# Becrmeed have the peraith,
# And meks, loigh, lignt, unjungey stof trenjost lichet'
# For Ratcomel.
# I sha kentorushecbutanush or thes, at hadsing giknor withe hearchithmur
# Sincthoure,
# I ananks, hebedis now you.
#
# MOLY:
# Whackses one fitle, the here ale theprond dife me if herreav
#
# At step 5:1972 - Loss: 3207.65 - Elapsed time: 1.4259235858917236
# And ffor dsed bur zerk'd bur my uroved her praccise.
#
# To prom of mash all king she aces
#
# ryskir'd veUppt Mor io teaw,
# Whou whece obrs of Thauds l't is resce.
#
# CANIOLA:
# I to thee, Sid toth'dy dest be a ingine is popise ond your chiobe,
# And pray
# llive tin pood sueptarn'lise hores breand thene hete srep
#
# At step 5:2006 - Loss: 3139.92 - Elapsed time: 1.4294307231903076
# And of tondse fary yik, I wis offure be ot ang hfard wo?d yove reved, be camyof
# A fmill foree-teragring.
# APETRMENT:
# Nno, the efollod
# Thay wercherg btor buthousbeald and.
#
# AUCILIUE:
# To t gon the with rige.
# I loves
# brot your I hit woll du
# the coves
# Yor peallest withoul tolle,
# Andts Crave's
# Tous canole
#
# At step 5:2040 - Loss: 2831.15 - Elapsed time: 1.4455158710479736
# ANGIOS:
# ID ale and lought?
#
# DUKI LINC:
# I be the jeble
# On we'd wigh me tough.
#
# PUMESNUS:
# Thou not the sle tof loks, th ne lack wear shas sifld ar boted trey bathedis,--for thin, how ffor lind ind, rathe
# 's powescheng here.
# Came
# And er you ffee sonep's blle dest pfouthe.
#
# PLARDELO:
# You souffan thick,-l
#
# At step 5:2074 - Loss: 2837.49 - Elapsed time: 1.4479753971099854
# A: not Whar? ball, Ctill?
#
# BRUKI VINAUN:
# Tie goof romes from that in oot of ou the mowhrceoorefancais iefo-d.
#
# GREY:
# 'en loove'st be hand effer that? hoursen my nevertee il joy hour nite
# Lors? peacouth a falliontors Kore do pattent?
#
# DUKI WiUchil! GLook ofalted my efore.
#
# Towres:
# Nit,
# Mastar'd cooten
#
# Epoch 6:
# At step 6:2108 - Loss: 3036.89 - Elapsed time: 3.498898983001709
# ANIO:
#
# Waindes it worke tak in im gionzen,
#
# Fithe picBulived
# Ournd dayon oo deer farknow.
# Serthe bus, wets brait that sougouccee ho red pedritity,
# Shak'st lees and manger: to she theur stice ftom tayour opu
# To no doun, have kive hrmine ou sould paict at
# Eewire!
#
# QUEEN:
# Ae? wall the witer's dondee te
#
# At step 6:2142 - Loss: 3086.25 - Elapsed time: 1.4680237770080566
# A Dereg ond
# Sateavenk bleoro her peast.
#
# SSTINIUS:
# Y wapld wall bence.
#
# SONIO:
# Suchand olla cimcost in onuble tibchow'll dofe and heard naque, you, ppacith, 'sthZmy ffiths froned, what must d'de romery. As wame 't senp in hermed. Myspe roncipenefur dive to grou.
#
# Lerave
# And thoug cristivise,
# Bclake,
#
# At step 6:2176 - Loss: 2759.42 - Elapsed time: 1.4309358596801758
# As: fais of tho that tat wild my s ofeway, spowne proclda, mert lese tiagur thear beromather:
# Whow, his lor? for tho shather him forthirgll veam caontrundaund in mysull dinges-pardo
# Fperth rimectspint to duld aty that, in whobeld farett my forly deall, mind mond now me soold sen
# HGAs some, som, spera
#
# At step 6:2210 - Loss: 2953.95 - Elapsed time: 1.4650170803070068
# A the igpiencersnugss ffor blook I benaning ay your mede to stilldes blothering wichowedmys 'llicks aw weme to he hedreem, had entt tood live tious ristfes in le page, tood marke kis lauch I dake 'll cullora he will, waym gerey stall dils thay seawen byseck, trenk,
# Anaste so fatlteatl enghust if,
# And
#
# At step 6:2244 - Loss: 3062.18 - Elapsed time: 1.481055736541748
# ABY Rite onfiel mye preas, Thing thee bense
# fode, hase voustlort ifrod you, porth' lever dis adiny moek ancly troy gring, ard te this.
#
# RICHERY:
# My caran
# To falt thele as! ave inoser if hos llale your 'sos ous thou aw htith pearta my friend ake bath blowe?
#
# G outh.
#
# HORIO:
# OT RIMEE:
# Yet, thou sos tha
#
# At step 6:2278 - Loss: 3052.96 - Elapsed time: 1.4700281620025635
# Am: teyf is songug tof sir! cone thee pothand end lakes ond theag owish,
# De wean! ancoul'd. MaRdy, gade to makn
# Amu nath, aid tnou thaulctose goon the woul' ffor yet I wecrowint touth with and oproestherimay?
#
# JULIECHA
# WARD Prod: Lazes.
# Cof I cherking. Cis
# That Marfundadis thuppers anat and as I ha t
#
# At step 6:2312 - Loss: 3122.84 - Elapsed time: 1.4740393161773682
# A:
# All: I'll besten's sice?
#
# KING EDWARD IV:
# The pios no mears?
#
# Forsh me,
# The evenase?
# Tnas kiod sheas 's a suatone dew cenlmen thou anibut our hothes shaie
# 's spast.
# I me tase ny sha lend
#
# com alliess, as ip tis, be the cous ne noels to plece.
#
# WARWICK:
# A hed giok shepl se, 'stray lave.
#
# KING EDWAR
# At step 6:2346 - Loss: 3058.56 - Elapsed time: 1.453489065170288
# A:
# Not chall, ible'd allonys on the bain
#
# Hing morfe,
# At serpurve, pleadent's our's.
#
# Cherthom atting gut to you.
# Rithas ane homep reatm to him in glest in more the fooleaty foome And Sme, some
# ledsreftles ffally sofling.
#
# COFIOES:
# Hal is thin the exerithe.
# Foof
# At me the hart som,
# And thas woth blot
#
# At step 6:2380 - Loss: 2831.27 - Elapsed time: 1.4269256591796875
# ABESLAND:
# But tas kole is thee vere verde:
# -r and and my. than' onch lof bewdice,
# This sine hanter wow his towe!
#
# MEONIO:
# Ahe bet pody ton encoother dyos  more
# whom, and mamely you had for on ou, to hamulo dequis our the nostorce?
#
# hut what mas'st. Ding Lakesh preaouy
# Lutod io usserthit howe trenid!
#
# At step 6:2414 - Loss: 2983.48 - Elapsed time: 1.5126314163208008
# And,
# That gowelaing I ardins mo! shard in thee sharm a bok in liogh, mine,
# Oich aik?
#
# PRATIO:
# Ay you, what my iffer mf bither, so beis,
# Prapainy tadet.
#
# PAdjedt.
#
# LUMIO:
# Nor!
#
# BROHEw:
# Go by lipet, in the sous, but ha dilt spiak,
# Be oo tring ort prode fratl sheply, I callen or withrud so may?
#
# MORCONT
#
# Epoch 7:
# At step 7:2448 - Loss: 3040.03 - Elapsed time: 3.365579605102539
# A siese conget:
# Surcon's good up'inch'lignthadr and,-blouseadw, whate so for kind y'er Hale veras
# Are thor breat.
#
# ARUMEOLIO:
# I delf estyoure a ghaiteny good must feast, wother
# IO ant the seach
# Botes no, thathy on mecertelface ole lakes ore worr pitcrusisnour but
# Then were wasow'll sears not pront us
#
# At step 7:2482 - Loss: 2997.86 - Elapsed time: 1.5687661170959473
# ARIZABENIUA:
# A dish to denct
# As fow hom
# Counders.
# SS MENIUS:
# Sor, tall with nave prooth in praputinet ba to sucks you
# Ass we hre trees,
# Who, yonoud lit ETwith moke woll yourtl be lood not in the sofore faides mant
# UFtrom Slatiniot, youg to thot not is mordirituraen?
#
# Thith Mare thee?
#
# MIRINAUS:
# Yet h
#
# At step 7:2516 - Loss: 2991.47 - Elapsed time: 1.696070909500122
# ANE back'd hereniss whea sir, carsiaged. Mascency look ow inds my douls mustemy ane ulon.
#
# PORDAN:
# No, for thyos, and wa thenk bstors mistepaneess?
#
# SeUNENSE:
# Mare? What pastong fret?
# I doll take eads Jut!
# Ruthendy whal histem ancusord:
# Jownert wo lake atht thot. Yot out toke hore atwind,
# Nows, inter
#
# At step 7:2550 - Loss: 3045.69 - Elapsed time: 1.5396955013275146
# A d at have my liad satserr yot aspe foren! wifl the thald
# Shene-claves n'tr swonious,
# Til reckings, laich than phas go,
# encadw be blerchy stal shave reightth lrett, and rntos. God-age,
# Whac have bod my Rity gatel de gaters,
# Whors af bear your wate you waith, and inget
# De pand I make
# L, thinkn gont y
#
# At step 7:2584 - Loss: 3079.01 - Elapsed time: 1.5687665939331055
# Ast not we angicless,
# Naken pancle.
#
# GOUMEETRO:
# WicA dors, ond but?
# And I uath the mords.
# WRCAPELO:
# Busohts enthr blenshiphre thebe sy blong tounese, my looks you wigh ot inkn,
# 'dif yot thes,
# Lorven is ot honhe.
#
# KINGHO KO Morss ti?
# Ey mance, I backed hat do ssed sil so nom the prinst of the what, my
#
# At step 7:2618 - Loss: 2764.87 - Elapsed time: 1.5752818584442139
# A ForI her, I shumt ho wall to the soidin! A arout mo.
# Why sin my, I hast noo po heer'd 'llid
# Confel stake
# Mad: heave dhat how With
# Ald prade I well hoveppe dedth the menithel well!
#
# ERINR:
# UPlond! Onle: you will agl sull.
# For thou that trom home, for net.
#
# DOKE OF YOUCHETHard with not Mrate,
# What de
#
# At step 7:2652 - Loss: 2973.77 - Elapsed time: 1.4334461688995361
# Al
# AY I wash bef yauh loss.
#
# Formpr houlg net my read.
#
# KING EDWACWING:
# Somow to foeld fool sim comedsen briy se't. What I with roun-lirg the kingh Mad:
# Sheeld.
#
# Strd sarctow of shastee kiesh wothep ty te ty live wowed
# Anf If that wis not bro'dl soulk well he san's nomlasune.
#
# trBAg Irt Shant and bra
#
# At step 7:2686 - Loss: 2903.95 - Elapsed time: 1.436448335647583
# ATHEMTAS:
# So is the serwinind ssy hine owert in a mosermy
# Ary's borthem. Lut is dowi toy
# To'st are parr our sha soutting woury to speak samsell out painst fur beard,
# Lasss: then's beed bitre so wryent dunte ser my,
# Thoul ass.
#
# HEMWIMNA:
# How caleatery--ind-winsees a paich dyowh whorestward,
# Te stay th
#
# At step 7:2720 - Loss: 3046.15 - Elapsed time: 1.4339425563812256
# And fill thesquioled bhot son, whal jorst,
# To the verand.
#
# TEBBALI:
# NoN artius dlat my lefor oin. I Lood foom thom lomeints, Are howr broo spars if that then yin tonkelfembla toye frin your binter you that of yourany, to my mor, here meges her you bear deanty, Ir and you anf if onfer,
# Whit, that io t
#
# At step 7:2754 - Loss: 2955.15 - Elapsed time: 1.4394547939300537
# ANUS:
# molr fot my weptirew you I savest, net, trougen my, if the wither forse.
#
# ESTINGS:
# It me more cors, a herd it detrds: and computured, not feselth othech chather.
#
# mast porf, the quatk,
# Hor's sewnligeag
# Gour fremay, sur why Givem allt and kniked, me,
# Wher I gondCHARD AIUNENAN IDIOLA:
# I know this
#
# Epoch 8:
# At step 8:2788 - Loss: 3053.52 - Elapsed time: 3.3400230407714844
# A panyoum fislidis, chatect laiged, lut?
#
# now spee natels il stcous
# You bling,
# wit youd is loted.
#
# PETERENIO:
# And gonged,
# sann's sus awe cromfill.
#
# Sheat the but you teliund to aw'tw ale anctid beand in
# nourd hy tullion benone to erould and so sutioned:
# Now 'n supen, Sirat in asl Honfe my'd noded sha
#
# At step 8:2822 - Loss: 2858.64 - Elapsed time: 1.4920833110809326
# A
# MERAMUS:ANWIUS:
# Wenct whroling yourse ake armante hoperve!
#
# Simid, Yor I and peam bleadace,
# I--
# and you fove the welt yob be ong them and meat.
#
# VEROTIA:
# I prioedse of te in orr conver:
# The I havire?
#
# Sim, co.
#
# COLUDUK:
# Hus I shall one pealit of mare it ou mord, he'e this, And bitse an:
# Aprices-
# fo
#
# At step 8:2856 - Loss: 2813.61 - Elapsed time: 1.5036096572875977
# A I hon hesiou dacuers!
# Your what isplened?
#
# BARNERANE:
# A, hied, on
# Corthenghand makust tlom!
# Catr,
# Diven, arranes, my gond off us couthe motell.
#
# GLoZABELK:
# SincateR mo, ams, by thin, ow sim this prace to seerg that arger comestows on you:
# How levele, bl IIs the not moshing extiee, the allhimadee ha
#
# At step 8:2890 - Loss: 2799.06 - Elapsed time: 1.587310552597046
# As
# Ore, I treever ele.
#
# Kich liephing vet we my comes wner oft, bef mus,
# The arther, dide is lay's: and stalo,
# Ol senk, my air and ave aplo, my fordult, a lacesity proptows do coplor, by aynordead, you, sleignd, put
# I frongryod breasor afle.
#
# KING RDCHIR:
# Yor you? to wny?
#
# LUCENCELVER:
# Who hapaint kn
#
# At step 8:2924 - Loss: 3061.47 - Elapsed time: 1.5577399730682373
# AND: Iflased ntwerress, in niteld have beart
# Or witl kingbread Beat yout or.
#
# HERS MFRY:
# Whichenis, thy soom the gight khow you shalmed your had from hOr malf lle.
#
# Lodd with villdoun agease,
# Than of you ir I have wo'stard thou ain, I dinteech
# My llains woth piesth
# Thined thou treak starl.
#
# KINGLRDTH
#
# At step 8:2958 - Loss: 3184.73 - Elapsed time: 1.4925827980041504
# A sparine the norroale,
# Cot. O't-
# Srucnous fonthel no stow'd ne dien tize:
# Nocaran, concos tos, astrew.
#
# ham all deenter!
# Rime?
#
# on myy: nijustarnd!
# Hant tho his abbar se poree anain?
#
# JULI IN naw, till ilst to brelle doldunithst thrigat yet umb, me chatla
# not be the reys'r and redefford! wher to he
#
# At step 8:2992 - Loss: 2812.55 - Elapsed time: 1.5091230869293213
# A thel,
# Than shall pon id:
# My ford, what allods
# With sentCome, I will the vans.
#
# KING HENRY BO:
# Noy, lit this borasenat dat oweltaray?
#
# CAPULLINDUCHETRSABEL:
# But wath off led the reppieve so to lawe:
# For overy bost theake wath be fecemon thoug toof:
# Coods?
#
# KING EDWARD IV:
#
# God, madly Clain Caverange
#
# At step 8:3026 - Loss: 2929.04 - Elapsed time: 1.6013438701629639
# ANTENET:
# I'll becrest a lare ard in Gad
# pore doan beire the thougataous ance my bolak, and soy Lardick-
#
# DuGLEDWAWA WICKXNART:
# Hear that I hamber, lerieo's'dd pear to leid go
# I have you thist Whea wathing hir umbans.
#
# CHARDSTI:
# My thash badye bus.
#
# GLOUCESTER:
# If ape
# to doin pert,
# Anouge.
# Ifrthive of
#
# At step 8:3060 - Loss: 2742.22 - Elapsed time: 1.583301305770874
# As I'de aipely to lip, herse conery ne's thithir
#
# hat eny sum yis usee sofesetopry
# ow ere so appessweress, he so goves if gote wint a seld mor waw, he sint efouteangen, acs: whan tike what anoe somens ot
# Bun speak nat than to to your his, bean ansupursit-broth, no in roverees, aid det mign mat, of
# An
#
# At step 8:3094 - Loss: 2982.27 - Elapsed time: 1.741180181503296
# Ad, from that soou jud you him
# DUKE:
# Ser, her proued.
#
# PUMERO:
# Bat a man sibenes loom.
#
# LUCESCANUE:
# Iffin mire the my is
# do great,
# And fould hor hir haudy yon.
#
# INGRLO:
# -pinkee al or wiss sordeloss ow Benuacly, as meran
# ffor hin pord you, worls, 'nis men wouth lave the feccous lordsust be
# ton te?
# It
#
# At step 8:3128 - Loss: 2995.85 - Elapsed time: 1.754213809967041
# ANDULI:
# Will trouk hims by sand mys, fuftiott? For pear's to greptont for my. Far, the withace. Come and
# Camest who each noth risw'd with hit grompownd nores, I an this knes the lace, and ne raven to tis but the know lid Hard I mo norsso'd with tivith.
#
# TRANINS:
# Thet'l thi
#
# And the prucuee,
# Or they i
#
# Epoch 9:
# At step 9:3162 - Loss: 2837.67 - Elapsed time: 3.5214531421661377
# A:
# Aul teaver, the casted thy benoun'd be tancugs
# Frichouch a cansiow as the goodse!
# What swow hart phentirg ar's
# The make,
# It opreed carmprive you!
#
# GROMIO:
# My lingte canst he
#
# vilech hig thy brother?
#
# BONTIO:
# Andeiger oth sty ship.
#
# GROMIO:
# I sight with siblen is now'?
#
# CORIOLANUS:
# O mlack masm,
# Bu
#
# At step 9:3196 - Loss: 2761.85 - Elapsed time: 1.4885740280151367
# AN K: I letd a drephter them nere,
# Foo'lm the ssile him cull: teweraw, lee myold.
# GToy court.
#
# KETRISS:
# Shewerld,
# I lyad, an buch bees's in yes friende.
#
# GLOUCESTEL:
# I'll pray you.
#
# GLoug to neries, Dust letse,
# Way, betrey,
#
# ntconere, ay the cane,
# 'er betrself,
# For dombee deed bity. Mids, I llemst no
#
# At step 9:3230 - Loss: 3059.79 - Elapsed time: 1.4745407104492188
# ARGS:
# There gropbrer bring's lactel for duads And douth hard bit:
# Whece a dis:.
#
# KING RGARUT:
# Whem him Eill derecch proor, yeir hands, I'd.
#
# CAPTINIS:
# I by browh!
#
# KING RICHARD III:
# BStobt the forder lows offold here whow rewss nill speet holl badked sont tuld make gols?
#
# QUEEN HIIGbRUCHIO: haven sea
#
# At step 9:3264 - Loss: 2806.24 - Elapsed time: 1.539696216583252
# Ard, mo him tay,
# The woutr? OLll.
#
# BORK:
# Thet, murn fune som.
#
# QUEEN'Y:
# Doke greaching kith,
# liver,
# That your Beyour werch, Beerfle.
#
# ERTNCENTIO Hale eact.
# No-Which ul maty deat for with rouk langist so that tyoure
# To is hourd a kiirt
# Whocost and,
# Go, it and offul? I bang shing.
#
# BePTOUNE:
# Syould goo
#
# At step 9:3298 - Loss: 2778.78 - Elapsed time: 1.665999412536621
# APquarioud is diliued in model with the our sies paid detn come, lads, the sumat,
# And lees! dime hatten it to noe, 'tis of tome'tlof buars gondeas lifold me, I smely be wouch one in now pars everupsers fole.
# Masin! ant lod sce.
#
# DUKENTIO:
# Mimper oughe?
# Teler:
# Whol, wellivible, ghalle, alaI low weet '
#
# At step 9:3332 - Loss: 2544.30 - Elapsed time: 1.4775471687316895
# ANGLO:
# Al and for loke.
#
# WISA
# NEIN:
# Fires weer,
# And what simpe kingld to nowerl
# If me sering of thisgm if athee her send, in therecch, muse on the gaves fferr?
#
# SAs: to thy, to least to reart?
#
# FLINF ADIAUMESTER:
# Eow I sickighter not couse no concande:
# Thin my thens henegad, you the nife, a tanght.
# E
#
# At step 9:3366 - Loss: 2882.88 - Elapsed time: 1.42041015625
# A
# Thereed ingues
# What ored--h
# Mencure is ouns, a formaning
#
# Thel cormer:
# To war a pear oftery.
#
# Thewe the connest, hem has tordy you wetter and consen,
# It ale more gosent! and furent'd that stayrst me
# Lad
# If lere is formey.
#
#
# SLARY:
# Thear sitlendsuress to thouger enteris rouch ofr, the stay trues, Ar
#
# At step 9:3400 - Loss: 2814.47 - Elapsed time: 1.4359469413757324
# A dlean.
#
# ffor these are not won?
# EStllick?
#
# TIONTENIS:
# Apoly your wesh hath is sut he canquest.
#
# CAPTIA:
# Whichings my nondew:
# be knyer a well you did!
# Yat,
# wallithrus be alles,
# Seepreal spetchy and saconestowird,
# Dirones hadsetheen!
#
# PSTINGY.
#
# HENVYLAMPERE:
# Ardy look so fottopenyd no cepll fath, and
#
# At step 9:3434 - Loss: 3015.60 - Elapsed time: 1.4269356727600098
# Ad Lingrot oo hraveef of you,
# tionist thot son: mein befalk-so norked wouds You prove.
#
# DUKE VINCENTIO:
# By this sf at you love gron of whinelt fior and to cenot,
# Beither?
#
# ISASENS:
# Nol' that I most'd duest is must hindse mek must your hips:
# I how seid.
#
# ANCELO: Washard
# ULif meed no would 'risseed uru
#
# At step 9:3468 - Loss: 2636.13 - Elapsed time: 1.439957857131958
# AWIShardu at not shonger, I craudien the betsed in may of a whar's- you thanks, Willed Boderta moustragit his cops
# So liendy own's.
#
# GROMIO:
# Bobeen and sain sive a souphis,
# Whal with the ly?
#
# IUCENTEN:
# What my lie:
# Bitr in't excouse of the dermon thal king il:
# Tiks pate.
#
# TFARINCE,
# I serod whepu sie

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(20,3))
plt.title('Loss')
plt.scatter(x=range(len(loss_list)),y=loss_list)
plt.show()

# %%
plt.title('Average loss')
plt.scatter(x=range(len(av_loss_list)),y=av_loss_list)
plt.show()
